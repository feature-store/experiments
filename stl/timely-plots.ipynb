# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_formats = ['svg']

import seaborn as sns
sns.set(style='whitegrid', palette='muted')

import json
import re
from glob import glob
import msgpack
import pickle
from sktime.performance_metrics.forecasting import mean_squared_scaled_error

# %%
loss_paths = sorted(glob("result/online_1_slide/experiment_*/analysis/loss.csv"))
server_config_paths = sorted(glob("result/online_1_slide/experiment_*/server_config.json"))
system_metrics_paths = sorted(glob("result/online_1_slide/experiment_*/analysis/system_df.csv"))
predictions_paths = sorted(glob("result/online_1_slide/experiment_*/analysis/predictions.csv"))

# loss_paths = sorted(glob("result/10-13-extended/experiment_*/analysis/loss.csv"))
# server_config_paths = sorted(glob("result/10-13-extended/experiment_*/server_config.json"))
# system_metrics_paths = sorted(glob("result/10-13-extended/experiment_*/analysis/system_df.csv"))
# predictions_paths = sorted(glob("result/10-13-extended/experiment_*/analysis/predictions.csv"))


# loss_paths = sorted(glob("result/online_1_slide_friday_336_12_15_18_fits//experiment_*/analysis/loss.csv"))
# server_config_paths = sorted(glob("result/online_1_slide_friday_336_12_15_18_fits/experiment_*/server_config.json"))
# system_metrics_paths = sorted(glob("result/online_1_slide_friday_336_12_15_18_fits/experiment_*/analysis/system_df.csv"))
# predictions_paths = sorted(glob("result/online_1_slide_friday_336_12_15_18_fits/experiment_*/analysis/predictions.csv"))

# %%
def load_results(folder):
    loss_paths = sorted(glob(f"{folder}/experiment_*/analysis/loss.csv"))
    server_config_paths = sorted(glob(f"{folder}/experiment_*/server_config.json"))
#     system_metrics_paths = sorted(glob(f"{folder}/experiment_*/system_df.csv"))
    predictions_paths = sorted(glob(f"{folder}/experiment_*/analysis/predictions.csv"))
    server_config_paths = server_config_paths[-len(predictions_paths):]
    result = []
    
#     print(list(map(len, [server_config_paths, loss_paths, predictions_paths])))
    for conf_path, loss_path, predictions_path in zip(
        server_config_paths, loss_paths, predictions_paths
    ):
        conf = json.load(open(conf_path))
#         print(conf)
        loss_df = pd.read_csv(loss_path)
#         system_df = pd.read_csv(system_metrics_path)
        prediction_df = pd.read_csv(predictions_path)

        if conf["use_per_key_slide_size_plan"]:
            slide_side = re.match(".*plan_(.*).json", conf["per_key_slide_size_plan_path"]).group(1)
        else:
            slide_side = conf["global_slide_size"]
#             print(slide_side)


#         max_cpu = int(system_df.groupby("time")["cpu"].sum().mean())
        total_loss = loss_df["loss"].dropna().sum()
        log_loss = np.log10(loss_df["loss"].dropna().sum())
        num_missing_keys = loss_df["loss"].isna().sum()
        total_predictions = len(prediction_df)

        result.append(
            {
                "slide_size": slide_side,
                "total_loss": total_loss,
                "mapper_replicas": conf["map_num_replicas"],
#                 "cpu": max_cpu,
                "num_mapper": conf["map_num_replicas"],
                "num_missing_keys": num_missing_keys,
                "total_predictions": total_predictions,
                "log10_loss": log_loss,
                "loss_path": loss_path,
                "predictions_path": predictions_path,
            }
        )

    return pd.DataFrame(result)
# result_df = result_df[result_df.total_predictions > 10000]

# %%
result_df = load_results("../timely-experiments/result/online_1_slide/")
result_df["policy_name"] = result_df.slide_size

slide_size_entries = result_df.slide_size.str.contains("max_fits").isna()
result_df.loc[slide_size_entries,"policy_name"]= result_df[slide_size_entries].policy_name.map(lambda x: f"static-{x}")
result_df.loc[~slide_size_entries,"policy_name"] = result_df[~slide_size_entries].policy_name.map(lambda s: f"lp-{s[-4:]}")

# %%
result_df
# Out:
#       slide_size  total_loss  mapper_replicas  num_mapper  num_missing_keys  \
# 0             24  167.784111                1           1                 0
# 1             48  222.005441                1           1                 0
# 2             96  205.843752                1           1                 0
# 3            144  202.728477                1           1                 0
# 4            196  197.159427                1           1                 0
# 5            256  190.993280                1           1                 0
# 6            336  202.304409                1           1                 0
# 7  max_fits_1000  190.317566                1           1                 0
# 8  max_fits_2000  193.972489                1           1                 0
#
#    total_predictions  log10_loss  \
# 0               9400    2.224751
# 1               9400    2.346364
# 2               9400    2.313538
# 3               9400    2.306915
# 4               9400    2.294818
# 5               9400    2.281018
# 6               9400    2.306005
# 7               9400    2.279479
# 8               9400    2.287740
#
#                                            loss_path  \
# 0  ../timely-experiments/result/online_1_slide/ex...
# 1  ../timely-experiments/result/online_1_slide/ex...
# 2  ../timely-experiments/result/online_1_slide/ex...
# 3  ../timely-experiments/result/online_1_slide/ex...
# 4  ../timely-experiments/result/online_1_slide/ex...
# 5  ../timely-experiments/result/online_1_slide/ex...
# 6  ../timely-experiments/result/online_1_slide/ex...
# 7  ../timely-experiments/result/online_1_slide/ex...
# 8  ../timely-experiments/result/online_1_slide/ex...
#
#                                     predictions_path policy_name
# 0  ../timely-experiments/result/online_1_slide/ex...   static-24
# 1  ../timely-experiments/result/online_1_slide/ex...   static-48
# 2  ../timely-experiments/result/online_1_slide/ex...   static-96
# 3  ../timely-experiments/result/online_1_slide/ex...  static-144
# 4  ../timely-experiments/result/online_1_slide/ex...  static-196
# 5  ../timely-experiments/result/online_1_slide/ex...  static-256
# 6  ../timely-experiments/result/online_1_slide/ex...  static-336
# 7  ../timely-experiments/result/online_1_slide/ex...     lp-1000
# 8  ../timely-experiments/result/online_1_slide/ex...     lp-2000

# %%
plt.figure(figsize=(10,4))

slide_sizes = result_df[result_df.slide_size.str.contains("max_fits").isna()]
costs = result_df[~result_df.slide_size.str.contains("max_fits").isna()]

# hues = result_df.policy_.unique().tolist()
# slide_size_hues = list(sorted(static_results.policy_name.tolist()))
# cost_hues = list(sorted(lp_results.policy_name.tolist()))

# hue_order = slide_size_hues + cost_hues

ax = sns.barplot(data=result_df, y="total_loss", x="policy_name") #, hue_order=hue_order)
plt.tight_layout()
plt.title("Anomaly Detection on Timely: Varying Policies")
plt.legend(ncol=2)
plt.xlabel("Policy")
plt.ylabel("Total session loss")
plt.ylim(0, 300)
for i in range(7):
    ax.patches[i].set_alpha(0.5)
for i in range(7, 9):
    # ax.patches[i].set_hatch("/")
    ax.patches[i].set_edgecolor("black")
# Out:
# No handles with labels found to put in legend.

# %%
result_df
# Out:
#       slide_size  total_loss  mapper_replicas  cpu  num_mapper  \
# 0  max_fits_1000  122.293850                1  346           1
# 1  max_fits_1200  126.441513                1  363           1
# 2  max_fits_1500  136.689295                1  363           1
#
#    num_missing_keys  total_predictions  log10_loss  \
# 0                 0              64400    2.087405
# 1                 0              64400    2.101890
# 2                 0              64400    2.135735
#
#                                            loss_path  \
# 0  result/online_1_slide/experiment_1634249630/an...
# 1  result/online_1_slide/experiment_1634250435/an...
# 2  result/online_1_slide/experiment_1634251238/an...
#
#                                     predictions_path
# 0  result/online_1_slide/experiment_1634249630/an...
# 1  result/online_1_slide/experiment_1634250435/an...
# 2  result/online_1_slide/experiment_1634251238/an...

# %%
num_mapper = 6
plt.title(f"Impact of Slide Size on Loss for {num_mapper} Parallel Trainers")

mapper_n_slide_size = slide_sizes[slide_sizes.num_mapper == num_mapper]
sns.barplot(data=mapper_n_slide_size, x="slide_size", y="total_loss")
# Out:
# <AxesSubplot:title={'center':'Impact of Slide Size on Loss for 6 Parallel Trainers'}, xlabel='slide_size', ylabel='total_loss'>

# %%
result_df.slide_size.unique()
# Out:
# array([24, 48, 96, 144, 196, 256, 336, 'max_fits_1000', 'max_fits_1200',
#        'max_fits_1500', 'max_fits_1800', 'max_fits_2000', 'max_fits_2500'],
#       dtype=object)

# %%
result_df
# Out:
#        slide_size  total_loss  mapper_replicas  cpu  num_mapper  \
# 0              24  299.125407                1    7           1
# 1              24  299.638589                1   14           1
# 2              48  303.626217                1   12           1
# 3              96  277.081937                1   15           1
# 4             144  310.241212                1   11           1
# 5             196  287.055665                1    9           1
# 6             256  299.461087                1   10           1
# 7             336  292.920911                1   10           1
# 8   max_fits_1000  284.254993                1   11           1
# 9   max_fits_1200  290.988583                1   11           1
# 10  max_fits_1500  292.897788                1   11           1
# 11  max_fits_1800  283.488051                1   10           1
# 12  max_fits_2000  303.814699                1   11           1
# 13  max_fits_2500  284.653700                1   10           1
# 14             24  277.093052                2    8           2
# 15             48  289.743647                2   12           2
# 16             96  286.642725                2   12           2
# 17            144  334.655255                2   11           2
# 18            196  291.298942                2   12           2
# 19            256  307.872823                2   10           2
# 20            336  313.063820                2    8           2
# 21  max_fits_1000  300.631396                2   11           2
# 22  max_fits_1200  299.987864                2   12           2
# 23  max_fits_1500  281.370229                2   12           2
# 24  max_fits_1800  273.663244                2   10           2
# 25  max_fits_2000  312.851358                2   11           2
# 26  max_fits_2500  301.515658                2   11           2
# 27             24  315.223481                4   15           4
# 28             48  291.588980                4   14           4
# 29             96  275.878948                4   12           4
# 30            144  300.470728                4   13           4
# 31            196  277.651175                4   16           4
# 32            256  314.740806                4   15           4
# 33            336  288.671345                4   15           4
# 34  max_fits_1000  286.571607                4   12           4
# 35  max_fits_1200  294.788095                4   13           4
# 36  max_fits_1500  304.971294                4   15           4
# 37  max_fits_1800  316.721039                4   13           4
# 38  max_fits_2000  303.200106                4   11           4
# 39  max_fits_2500  311.589447                4   17           4
# 40             24  290.903384                6   14           6
# 41             48  313.457427                6   16           6
# 42             96  291.550889                6   18           6
# 43            144  308.400797                6   17           6
# 44            196  327.186445                6   14           6
# 45            256  295.702213                6   15           6
# 46            336  309.802355                6   16           6
# 47  max_fits_1000  302.475478                6   14           6
# 48  max_fits_1200  297.478209                6   18           6
# 49  max_fits_1500  306.680717                6   17           6
# 50  max_fits_1800  296.650196                6   14           6
# 51  max_fits_2000  307.692772                6   15           6
# 52  max_fits_2500  296.275353                6   15           6
# 53             24  279.869736                1    7           1
# 54             48  291.687904                1    9           1
# 55             96  285.203425                1   12           1
# 56            144  288.968030                1    9           1
#
#     num_missing_keys  total_predictions  log10_loss  \
# 0                  0              64400    2.475853
# 1                  0              64400    2.476598
# 2                  0              64400    2.482339
# 3                  0              64400    2.442608
# 4                  0              64400    2.491699
# 5                  0              64400    2.457966
# 6                  0              64400    2.476340
# 7                  0              64400    2.466750
# 8                  0              64400    2.453708
# 9                  0              64400    2.463876
# 10                 0              64400    2.466716
# 11                 0              64400    2.452535
# 12                 0              64400    2.482609
# 13                 0              64400    2.454317
# 14                 0              64400    2.442626
# 15                 0              64400    2.462014
# 16                 0              64400    2.457341
# 17                 0              64400    2.524598
# 18                 0              64400    2.464339
# 19                 0              64400    2.488371
# 20                 0              64400    2.495633
# 21                 0              64400    2.478034
# 22                 0              64400    2.477104
# 23                 0              64400    2.449278
# 24                 0              64400    2.437216
# 25                 0              64400    2.495338
# 26                 0              64400    2.479310
# 27                 0              64400    2.498619
# 28                 0              64400    2.464771
# 29                 0              64400    2.440719
# 30                 0              64400    2.477802
# 31                 0              64400    2.443500
# 32                 0              64400    2.497953
# 33                 0              64400    2.460404
# 34                 0              64400    2.457233
# 35                 0              64400    2.469510
# 36                 0              64400    2.484259
# 37                 0              64400    2.500677
# 38                 0              64400    2.481729
# 39                 0              64400    2.493583
# 40                 0              64400    2.463749
# 41                 0              64400    2.496179
# 42                 0              64400    2.464714
# 43                 0              64400    2.489115
# 44                 0              64400    2.514795
# 45                 0              64400    2.470855
# 46                 0              64400    2.491085
# 47                 0              64400    2.480690
# 48                 0              64400    2.473455
# 49                 0              64400    2.486686
# 50                 0              64400    2.472245
# 51                 0              64400    2.488117
# 52                 0              64400    2.471696
# 53                 0              64400    2.446956
# 54                 0              64400    2.464918
# 55                 0              64400    2.455155
# 56                 0              64400    2.460850
#
#                                             loss_path  \
# 0   result/10-13-extended/experiment_1634112297/an...
# 1   result/10-13-extended/experiment_1634113101/an...
# 2   result/10-13-extended/experiment_1634113905/an...
# 3   result/10-13-extended/experiment_1634114709/an...
# 4   result/10-13-extended/experiment_1634115514/an...
# 5   result/10-13-extended/experiment_1634116318/an...
# 6   result/10-13-extended/experiment_1634117122/an...
# 7   result/10-13-extended/experiment_1634117926/an...
# 8   result/10-13-extended/experiment_1634118730/an...
# 9   result/10-13-extended/experiment_1634119534/an...
# 10  result/10-13-extended/experiment_1634120338/an...
# 11  result/10-13-extended/experiment_1634121143/an...
# 12  result/10-13-extended/experiment_1634121947/an...
# 13  result/10-13-extended/experiment_1634122751/an...
# 14  result/10-13-extended/experiment_1634123555/an...
# 15  result/10-13-extended/experiment_1634124359/an...
# 16  result/10-13-extended/experiment_1634125163/an...
# 17  result/10-13-extended/experiment_1634125967/an...
# 18  result/10-13-extended/experiment_1634126771/an...
# 19  result/10-13-extended/experiment_1634127575/an...
# 20  result/10-13-extended/experiment_1634128379/an...
# 21  result/10-13-extended/experiment_1634129183/an...
# 22  result/10-13-extended/experiment_1634129987/an...
# 23  result/10-13-extended/experiment_1634130791/an...
# 24  result/10-13-extended/experiment_1634131595/an...
# 25  result/10-13-extended/experiment_1634132399/an...
# 26  result/10-13-extended/experiment_1634133204/an...
# 27  result/10-13-extended/experiment_1634134008/an...
# 28  result/10-13-extended/experiment_1634134811/an...
# 29  result/10-13-extended/experiment_1634135615/an...
# 30  result/10-13-extended/experiment_1634136420/an...
# 31  result/10-13-extended/experiment_1634137224/an...
# 32  result/10-13-extended/experiment_1634138028/an...
# 33  result/10-13-extended/experiment_1634138832/an...
# 34  result/10-13-extended/experiment_1634139636/an...
# 35  result/10-13-extended/experiment_1634140440/an...
# 36  result/10-13-extended/experiment_1634141244/an...
# 37  result/10-13-extended/experiment_1634142048/an...
# 38  result/10-13-extended/experiment_1634142852/an...
# 39  result/10-13-extended/experiment_1634143656/an...
# 40  result/10-13-extended/experiment_1634144460/an...
# 41  result/10-13-extended/experiment_1634145264/an...
# 42  result/10-13-extended/experiment_1634146069/an...
# 43  result/10-13-extended/experiment_1634146873/an...
# 44  result/10-13-extended/experiment_1634147677/an...
# 45  result/10-13-extended/experiment_1634148482/an...
# 46  result/10-13-extended/experiment_1634149286/an...
# 47  result/10-13-extended/experiment_1634150090/an...
# 48  result/10-13-extended/experiment_1634150894/an...
# 49  result/10-13-extended/experiment_1634151698/an...
# 50  result/10-13-extended/experiment_1634152502/an...
# 51  result/10-13-extended/experiment_1634153306/an...
# 52  result/10-13-extended/experiment_1634154111/an...
# 53  result/10-13-extended/experiment_1634154915/an...
# 54  result/10-13-extended/experiment_1634155719/an...
# 55  result/10-13-extended/experiment_1634156523/an...
# 56  result/10-13-extended/experiment_1634157328/an...
#
#                                      predictions_path
# 0   result/10-13-extended/experiment_1634112297/an...
# 1   result/10-13-extended/experiment_1634113101/an...
# 2   result/10-13-extended/experiment_1634113905/an...
# 3   result/10-13-extended/experiment_1634114709/an...
# 4   result/10-13-extended/experiment_1634115514/an...
# 5   result/10-13-extended/experiment_1634116318/an...
# 6   result/10-13-extended/experiment_1634117122/an...
# 7   result/10-13-extended/experiment_1634117926/an...
# 8   result/10-13-extended/experiment_1634118730/an...
# 9   result/10-13-extended/experiment_1634119534/an...
# 10  result/10-13-extended/experiment_1634120338/an...
# 11  result/10-13-extended/experiment_1634121143/an...
# 12  result/10-13-extended/experiment_1634121947/an...
# 13  result/10-13-extended/experiment_1634122751/an...
# 14  result/10-13-extended/experiment_1634123555/an...
# 15  result/10-13-extended/experiment_1634124359/an...
# 16  result/10-13-extended/experiment_1634125163/an...
# 17  result/10-13-extended/experiment_1634125967/an...
# 18  result/10-13-extended/experiment_1634126771/an...
# 19  result/10-13-extended/experiment_1634127575/an...
# 20  result/10-13-extended/experiment_1634128379/an...
# 21  result/10-13-extended/experiment_1634129183/an...
# 22  result/10-13-extended/experiment_1634129987/an...
# 23  result/10-13-extended/experiment_1634130791/an...
# 24  result/10-13-extended/experiment_1634131595/an...
# 25  result/10-13-extended/experiment_1634132399/an...
# 26  result/10-13-extended/experiment_1634133204/an...
# 27  result/10-13-extended/experiment_1634134008/an...
# 28  result/10-13-extended/experiment_1634134811/an...
# 29  result/10-13-extended/experiment_1634135615/an...
# 30  result/10-13-extended/experiment_1634136420/an...
# 31  result/10-13-extended/experiment_1634137224/an...
# 32  result/10-13-extended/experiment_1634138028/an...
# 33  result/10-13-extended/experiment_1634138832/an...
# 34  result/10-13-extended/experiment_1634139636/an...
# 35  result/10-13-extended/experiment_1634140440/an...
# 36  result/10-13-extended/experiment_1634141244/an...
# 37  result/10-13-extended/experiment_1634142048/an...
# 38  result/10-13-extended/experiment_1634142852/an...
# 39  result/10-13-extended/experiment_1634143656/an...
# 40  result/10-13-extended/experiment_1634144460/an...
# 41  result/10-13-extended/experiment_1634145264/an...
# 42  result/10-13-extended/experiment_1634146069/an...
# 43  result/10-13-extended/experiment_1634146873/an...
# 44  result/10-13-extended/experiment_1634147677/an...
# 45  result/10-13-extended/experiment_1634148482/an...
# 46  result/10-13-extended/experiment_1634149286/an...
# 47  result/10-13-extended/experiment_1634150090/an...
# 48  result/10-13-extended/experiment_1634150894/an...
# 49  result/10-13-extended/experiment_1634151698/an...
# 50  result/10-13-extended/experiment_1634152502/an...
# 51  result/10-13-extended/experiment_1634153306/an...
# 52  result/10-13-extended/experiment_1634154111/an...
# 53  result/10-13-extended/experiment_1634154915/an...
# 54  result/10-13-extended/experiment_1634155719/an...
# 55  result/10-13-extended/experiment_1634156523/an...
# 56  result/10-13-extended/experiment_1634157328/an...

# %%
def plot_loss_over_time(num_mappers, slide_size):
    tmp_df = result_df[(result_df.slide_size == slide_size) & (result_df.num_mapper == num_mappers)]
    prediction_path = tmp_df.predictions_path.tolist()[0]
    predictions_df = pd.read_csv(prediction_path)

    # Compute loss
    predictions_df["loss"] = (predictions_df.pred - predictions_df.event_value) ** 2
    
    plt.figure()
    
    plt.title(f"Per-key Staleness vs Time (slide size {slide_size}, num_mappers {num_mappers})")
    sns.lineplot(data=predictions_df, x="timestamp", y="staleness", hue="key")
    plt.legend([],[], frameon=False)
    
    plt.figure()

    plt.title(f"Per-key Loss vs Time (slide size {slide_size}, num_mappers {num_mappers})")
    sns.lineplot(data=predictions_df, x="timestamp", y="loss", hue="key")
    plt.legend([],[], frameon=False)

# %%
plot_loss_over_time(1, "max_fits_1000")

# %%
plot_loss_over_time(1, 24)

# %%
plot_loss_over_time(6, 336)
# Out:
# 10000

# %%
slide_size_144 = mapper_4_slide_size[mapper_4_slide_size.slide_size == 144]
plt.scatter(x=list(range(len(slide_size_144))), y=slide_size_144.total_loss)

# %%
result_df.total_predictions

# %%
plt.figure(figsize=(10,3))
sns.barplot(data=result_df, hue="slide_size", y="num_missing_keys", x="cpu")
plt.tight_layout()

# %%
plt.figure(figsize=(10,3))
sns.barplot(data=result_df, hue="slide_size", y="total_predictions", x="cpu")
plt.tight_layout()

# %%
plan_file = "./offline/result/offline_1_slide/min_loss_plan_max_fits_1500.json"
vary_slide_plan = json.load(open(plan_file))

# %%
plt.figure(figsize=(15,3))
vary_slide_df = pd.Series(vary_slide_plan).to_frame().reset_index().rename(columns={"index": "key", 0: "slide_size"})
sns.barplot(data=vary_slide_df, x="key", y="slide_size")
plt.tight_layout()

# %%
from statsmodels.tsa.seasonal import STL

# %%
from statsmodels.tsa.seasonal import STL
data = [1.0 for _ in range(678)]
# %%time
stl = STL(data, period=168, robust=True)

# %%
# %%time
stl = STL(data, period=168, robust=True)
